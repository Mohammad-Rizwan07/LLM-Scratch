# %% [markdown]
# ## this is the testing page where testing for many other sources use cases happens

# %%
with open("extracted_text.txt", "r", encoding="utf-8") as f:
    content = f.read()
print("total characters:", len(content))
print(content[:100])  # Print the first 1000 characters for a quick check
# Out:
# total characters: 14507
# **Page 1**
#
# No.F.4/1/2023-PPD(pt.)
# Government of India
# Ministry of Finance
# Department of Expenditure

# %%
with open("google.txt", "r", encoding="utf-8") as f:
    content = f.read()
print("total characters:", len(content))
print(content[:100])  # Print the first 1000 characters for a quick check
# Out:
# total characters: 232200
# Google
# Google LLC (/ˈɡuːɡəl/ ⓘ , GOO-gəl) is an Google LLC
# American multinational corporation and te
